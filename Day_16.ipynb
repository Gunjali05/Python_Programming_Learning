# %%
#01 WAP to check type of set
s='hello'
print(s)
print(type(s))
# Out:
# hello
# <class 'str'>

# %%
#02 WAP to print single line 
s1="pune is clean city"
print(s1)
# Out:
# pune is clean city

# %%
#03 WAP to print multiple line
s1='''pune is 
clean city'''
print(s1)
# Out:
# pune is
# clean city

# %%
#04 WAP to print last index 
s[-1]
# Out:
# 'o'

# %%
#05 WAP to check lower case in string 
"HELLO".lower()
# Out:
# 'hello'

# %%
#06 WAP to check upper case in string 
"hello".upper()
# Out:
# 'HELLO'

# %%
#07 WAP to check title in string 
"hello world".title()
# Out:
# 'Hello World'

# %%
#08 WAP to check capitalize in string 
"hello".capitalize()
# Out:
# 'Hello'

# %%
#09 WAP to check strip in string
" hi ".strip()
# Out:
# 'hi'

# %%
#10 WAP to check right strip in string
"hii ".rstrip()
# Out:
# 'hii'

# %%
#11 WAP to check left strip in string 
" hii".lstrip()
# Out:
# 'hii'

# %%
#12 WAP to print length of string
len("pune")
# Out:
# 4

# %%
#13 WAP to print sorted in string
sorted("pune")
# Out:
# ['e', 'n', 'p', 'u']

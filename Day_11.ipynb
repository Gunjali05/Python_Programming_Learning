# %%
#01 WAP to check class of t1
t1 = ()
print(type(t1))
# Out:
# <class 'tuple'>

# %%
#02 WAP to print 10 to 60 number in tuple 
t2=(10,20,30,40,50,60)
print(t2)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
#03 WAP to print 4th index number in tuple 
t2[4]
# Out:
# 50

# %%
#04 WAP to print last number in tuple 
t2[-1]
# Out:
# 60

# %%
#05 WAP to print 20 to 60 and used 3 step number in tuple 
t2[1:5:3]
# Out:
# (20, 50)

# %%
#06 WAP to print length in tuple
len(t2)
# Out:
# 6

# %%
#07 WAP to print ascending order in tuple
sorted(t2)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
#08 WAP to print decending order in tuple 
sorted(t2,reverse=True)
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
#09 WAP to print count number in tuple 
t2.count(40)
# Out:
# 1

# %%
#10 WAP to print index in tuple 
t2.index(30)
# Out:
# 2

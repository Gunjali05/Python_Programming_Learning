# %%
#01 WAP to print same element
A={1,2,3,4,5}
B={4,5,6,7,8}
A.intersection(B)
# Out:
# {4, 5}

# %%
#02 WAP to print union element 
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#03 WAP to print difference of a of b
A.difference(B)
# Out:
# {1, 2, 3}

# %%
#04 WAP to print difference of a of b
B.difference(A)
# Out:
# {6, 7, 8}

# %%
#05 WAP to print difference
a=A.difference(B)
b=B.difference(A)
print(a.union(b))
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
#06 WAP to print type of d1
d1={}
print(type(d1))
# Out:
# <class 'dict'>

# %%
#07 WAP to print type of d2
d2=dict()
print(type(d2))
# Out:
# <class 'dict'>

# %%
#08 WAP to print key-value of dictionary
d3={1:'Ram',2:'sham',3:'jay',4:'vijay'}
print(d3)
# Out:
# {1: 'Ram', 2: 'sham', 3: 'jay', 4: 'vijay'}

# %%
#09 WAP to print sham 
d3[2]
# Out:
# 'sham'

# %%
#10 WAP to add om
d3[4]='om'
print(d3)
# Out:
# {1: 'Ram', 2: 'sham', 3: 'jay', 4: 'om'}

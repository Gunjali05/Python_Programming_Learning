# %%
#01 WAP to generate list of random numbers and make to different list as odd number list and even number list from original list 
list2 = [1,2,3,4,5,6,7,8,9]
odd=[]
even=[]
for i in list2:
    if i%2==0:
        even.append(i)
    else:
        odd.append(i)
print(f"Original list : {list2}\nEven number list: {even}\nOdd number list: {odd}")
# Out:
# Original list : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Even number list: [2, 4, 6, 8]
# Odd number list: [1, 3, 5, 7, 9]

# %%
#02 WAP to print type of s1
s1={}
print(type(s1))
# Out:
# <class 'dict'>

# %%
#03 WAP to print type of s2
s2= set()
print(type(s2))
# Out:
# <class 'set'>

# %%
#04 WAP to print element 
s3={1,2,2,1,3,4,5}
print(s3)
# Out:
# {1, 2, 3, 4, 5}

# %%
#05 WAP to add element 20 in set
s3.add(20)
print(s3)
# Out:
# {1, 2, 3, 4, 5, 'c', 20, 'a', 'b'}

# %%
#06 WAP to update element abc
s3.update("abc")
print(s3)
# Out:
# {1, 2, 3, 4, 5, 'c', 20, 'a', 'b'}

# %%
#07 WAP to add pune
s3.add("Pune")
print(s3)
# Out:
# {1, 2, 3, 4, 5, 'Pune', 'c', 20, 'a', 'b'}

# %%
#08 WAP to remove pune
s3.remove("Pune")
print(s3)
# Out:
# {1, 2, 3, 4, 5, 'c', 20, 'a', 'b'}

# %%
#09 WAP to discard a in set
s3.discard('a')
print(s3)
# Out:
# {1, 2, 3, 4, 5, 'c', 20, 'b'}

# %%
#10 WAP to print address as a output 
print(s3.discard)
# Out:
# <built-in method discard of set object at 0x000001F3C3D8FCA0>

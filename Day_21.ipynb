# %%
#01 WAP to create a lambda function to add of two numbers.
add=lambda a,b: a+b
add(5,2)
# Out:
# 7

# %%
#02 WAP to create a lambda function to subtract 0f two numbers.
sub=lambda a,b: a-b
sub(5,2)
# Out:
# 3

# %%
#03 WAP to create a lambda function to multiply of two numbers.
mul=lambda a,b: a*b
mul(5,2)
# Out:
# 10

# %%
#04 WAP to create a lambda function to division of two numbers.
div=lambda a,b: a/b
div(10,5)
# Out:
# 2.0

# %%
#05 WAP to create a lambda function to remainder of two numbers.
rem=lambda a,b: a%b
rem(5,2)
# Out:
# 1

# %%
#06 WAP to create a lambda function to quotient of two numbers.
quo=lambda a,b: a//b
quo(5,2)
# Out:
# 2

# %%
#07 WAP to create a lambda function to power 0f two numbers.
power=lambda a,b: a**b
power(5,2)
# Out:
# 25

# %%
#08 WAP to create a lambda function to square root of given numbers.
squ_root=lambda n: n**(1/2)
squ_root(4)
# Out:
# 2.0

# %%
#09 WAP to create a lambda function to cube root of given numbers.
cube_root=lambda n: n**(1/3)
cube_root(27)
# Out:
# 3.0

# %%
#10 WAP to create a lambda function to calculate the area of a square.
square = lambda s: s**2
square(2)
# Out:
# 4

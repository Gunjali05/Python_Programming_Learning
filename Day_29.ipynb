# %%
#01 WAP to calculate Salary Slip Generator
def salary_slip(basic):
    hra = basic * 0.20
    da = basic * 0.10
    pf = basic * 0.12
    net_salary = basic + hra + da - pf
    return net_salary

basic = float(input("Enter Basic Salary: "))
print("Net Salary = ₹", salary_slip(basic))
# Out:
# Enter Basic Salary:  20000
# Net Salary = ₹ 23600.0

# %%
#02 WAP to calculate Sales Commission
def commission(sales):
    return sales * 0.05
sales = float(input("Enter Sales Amount: "))
print("Commission = ₹", commission(sales))
# Out:
# Enter Sales Amount:  5000
# Commission = ₹ 250.0

# %%
#03 WAP to calculate Bonus Calculator
def bonus(salary):
    return salary * 0.15
salary = float(input("Enter Salary: "))
print("Bonus = ₹", bonus(salary))
# Out:
# Enter Salary:  40000
# Bonus = ₹ 6000.0

# %%
#04 WAP to calculate Internet Bill
def internet(months):
    return months * 600
months = int(input("Enter Number of Months: "))
print("Internet Bill = ₹", internet(months))
# Out:
# Enter Number of Months:  5
# Internet Bill = ₹ 3000

# %%
#05 WAP to calculate Car Rental Bill
def car_rent(days):
    return days * 1800
days = int(input("Rental Days: "))
print("Total Rent = ₹", car_rent(days))
# Out:
# Rental Days:  6
# Total Rent = ₹ 10800

# %%
#06 WAP to calculate Hotel Booking Discount
def hotel_bill(amount):
    if amount > 10000:
        amount -= amount * 0.20
    return amount
bill = float(input("Hotel Bill: "))
print("Final Bill = ₹", hotel_bill(bill))
# Out:
# Hotel Bill:  2000
# Final Bill = ₹ 2000.0

# %%
#07 WAP to calculate Fruit Shop Bill
def fruit_bill(apples, mangoes):
    return (apples * 120) + (mangoes * 90)
a = int(input("Apples (kg): "))
m = int(input("Mangoes (kg): "))
print("Bill = ₹", fruit_bill(a, m))
# Out:
# Apples (kg):  5
# Mangoes (kg):  6
# Bill = ₹ 1140

# %%
#08 WAP to calculate Employee Attendance
def attendance(total_days, present_days):
    return (present_days / total_days) * 100
total = int(input("Working Days: "))
present = int(input("Present Days: "))
print("Attendance =", attendance(total, present), "%")
# Out:
# Working Days:  6
# Present Days:  5
# Attendance = 83.33333333333334 %

# %%
#09 WAP to calculate Overtime Salary
def overtime(hours):
    return hours * 250
hours = int(input("Overtime Hours: "))
print("Extra Salary = ₹", overtime(hours))
# Out:
# Overtime Hours:  4
# Extra Salary = ₹ 1000

# %%
#10 WAP to calculate Printing Shop
def printing(pages):
    return pages * 3
pages = int(input("Pages: "))
print("Total Cost = ₹", printing(pages))
# Out:
# Pages:  6
# Total Cost = ₹ 18

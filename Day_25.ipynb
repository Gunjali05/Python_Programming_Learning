# %%
#01 WAP to find pi value
import math 
print(math.pi)
# Out:
# 3.141592653589793

# %%
#02 WAP to find euler value
import math 
print(math.e)
# Out:
# 2.718281828459045

# %%
#03 WAP to find hypotenius
import math 
print(math.hypot(2,4))
# Out:
# 4.47213595499958

# %%
#04 WAP to convert degree to radian
import math
print(math.radians(90))
# Out:
# 1.5707963267948966

# %%
#05 WAP to convert radian to degree
import math
print(math.degrees(1.5707963267948966))
# Out:
# 90.0

# %%
#06 WAP to print sum of two number
import math
a = 100
b = 200
result = a+b
print("SUM:",result)
# Out:
# SUM: 300

# %%
#07 WAP to print subtraction of two number
import math
a = 300
b = 200
result = a-b
print("SUB:",result)
# Out:
# SUB: 100

# %%
#08 WAP to print multiplication of two number
import math
a = 10
b = 20
result = a*b
print("Multi:",result)
# Out:
# Multi: 200

# %%
#09 WAP to print LCM of two number
import math
a = 12
b = 18
print(math.lcm(a,b))
# Out:
# 36

# %%
#10 WAP to print GCD of two number
import math
a = 12
b = 18
print(math.gcd(a,b))
# Out:
# 6

# %%
#01 WAP to print a replace to i in string
"happy".replace("a","i")
# Out:
# 'hippy'

# %%
#02 WAP to print join with elements in string
"-".join(['a','b','c'])
# Out:
# 'a-b-c'

# %%
#03 WAP to print split in string
"a,b,c".split(",")
# Out:
# ['a', 'b', 'c']

# %%
#04 WAP to print find value in string
"hello".find("e")
# Out:
# 1

# %%
#05 WAP to print index value in string
"hello".index("e")
# Out:
# 1

# %%
#06 WAP to print count in string
"banana".count("a")
# Out:
# 3

# %%
#07 WAP to print starting value is true 
"hello".startswith("he")
# Out:
# True

# %%
#08 WAP to print ending value is true 
"hello".endswith("lo")
# Out:
# True

# %%
#09 WAP to print alphabet are true 
"abc".isalpha()
# Out:
# True

# %%
#10 WAP to print numbers are true 
"123".isdigit()
# Out:
# True

# %%
#11 WAP to print alphabet and numbers both are true
"abc123".isalnum()
# Out:
# True

# %%
#12 WAP to print join and sort the string
"".join(sorted("pune"))
# Out:
# 'enpu'

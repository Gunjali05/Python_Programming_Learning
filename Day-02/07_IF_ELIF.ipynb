# %%
n1=50
n2=50
if(n1>n2):
    print(f"{n1} is greater than {n2}")
elif(n2>n1):
    print(f"{n2} is greater than {n1}")
elif(n1==n2):
    print(f"{n1} is equal to {n2}")
else:
    print("ERROR")
print("HELLO!")
# Out:
# 50 is equal to 50
# HELLO!
